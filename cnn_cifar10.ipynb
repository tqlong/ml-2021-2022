# %%
import torch
from torch import nn
import torchvision
from torchvision import transforms
import matplotlib.pyplot as plt
from collections import namedtuple
from sklearn.metrics import classification_report

# %%
## CIFAR-10
classes = ('plane', 'car', 'bird', 'cat',
          'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
TrainTest = namedtuple('TrainTest', ['train', 'test'])

def prepare_data():
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()
    ])
    transform_test = transforms.Compose([
        transforms.ToTensor()
    ])
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
    testset  = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
    return TrainTest(
        train=trainset,
        test=testset
    )

def prepare_loader(datasets):
    batch_size = 128
    trainloader = torch.utils.data.DataLoader(
        datasets.train, batch_size=batch_size, shuffle=True, num_workers=4)
    testloader = torch.utils.data.DataLoader(
        datasets.test, batch_size=batch_size, shuffle=False, num_workers=4)
    return TrainTest(
        train=trainloader,
        test=testloader
    )

class VGG16(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = self._make_layers()
        self.classfier_head = nn.Linear(512, 10)
        
    def forward(self, x):
        out = self.features(x)
        out = self.classfier_head(out.view(out.size(0), -1))
        return out
    
    def _make_layers(self):
        config = [64, 64, 'MP', 128, 128, 'MP', 256, 256, 256, 'MP', 512, 512, 512, 'MP', 512, 512, 512, 'MP']
        layers = []
        c_in = 3
        for c in config:
            if c == 'MP':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [
                    nn.Conv2d(in_channels=c_in, out_channels=c, kernel_size=3, padding=1),
                    nn.BatchNorm2d(c),
                    nn.ReLU6(inplace=True)
                ]
                c_in = c
        return nn.Sequential(*layers)
    
def get_trainer(model):
    loss = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    return loss, optimizer

def train_epoch(epoch, model, loader, loss_func, optimizer, device):
    model.train()
    running_loss = 0.0
    reporting_step = 60
    for i, (images, labels) in enumerate(loader):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        if i % reporting_step == reporting_step-1:
            print(f"Epoch {epoch} Step {i} ave_loss {running_loss/reporting_step:0.4f}")
            running_loss = 0.0
            
def test_epoch(epoch, model, loader, device):
    model.eval()
    ypred = []
    ytrue = []
    for i, (images, labels) in enumerate(loader):
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, dim=1)
        ypred += list(predicted.cpu().numpy())
        ytrue += list(labels.cpu().numpy())
    return ypred, ytrue

# %%
def main(PATH='./model.pth'):
    datasets = prepare_data()
    loaders = prepare_loader(datasets)
    model = VGG16()
    loss, optimizer = get_trainer(model)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    n_epoch = 10   
    model.to(device)
    for epoch in range(n_epoch):
        train_epoch(epoch, model, loaders.train, loss, optimizer, device)
        ypred, ytrue = test_epoch(epoch, model, loaders.test, device)
        print(classification_report(ytrue, ypred, target_names=classes))
        
        torch.save(model.state_dict(), PATH)
        
    return model

model = main()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# data 50000 10000
# in torch.Size([128, 3, 32, 32]) torch.Size([128])
# out torch.Size([128, 10])
# cuda:0
# Epoch 0 Step 59 ave_loss 2.0802
# Epoch 0 Step 119 ave_loss 1.7307
# Epoch 0 Step 179 ave_loss 1.5541
# Epoch 0 Step 239 ave_loss 1.3917
# Epoch 0 Step 299 ave_loss 1.2736
# Epoch 0 Step 359 ave_loss 1.2007
#               precision    recall  f1-score   support
#
#        plane       0.46      0.83      0.59      1000
#          car       0.83      0.70      0.76      1000
#         bird       0.34      0.50      0.40      1000
#          cat       0.34      0.59      0.43      1000
#         deer       0.57      0.25      0.34      1000
#          dog       0.75      0.20      0.32      1000
#         frog       0.72      0.67      0.69      1000
#        horse       0.78      0.48      0.60      1000
#         ship       0.69      0.82      0.75      1000
#        truck       0.83      0.61      0.71      1000
#
#     accuracy                           0.57     10000
#    macro avg       0.63      0.57      0.56     10000
# weighted avg       0.63      0.57      0.56     10000
#
# Epoch 1 Step 59 ave_loss 1.0846
# Epoch 1 Step 119 ave_loss 1.0282
# Epoch 1 Step 179 ave_loss 0.9561
# Epoch 1 Step 239 ave_loss 0.8886
# Epoch 1 Step 299 ave_loss 0.8875
# Epoch 1 Step 359 ave_loss 0.8620
#               precision    recall  f1-score   support
#
#        plane       0.55      0.83      0.66      1000
#          car       0.77      0.82      0.79      1000
#         bird       0.41      0.67      0.51      1000
#          cat       0.54      0.30      0.39      1000
#         deer       0.87      0.33      0.47      1000
#          dog       0.47      0.68      0.56      1000
#         frog       0.86      0.62      0.72      1000
#        horse       0.67      0.68      0.67      1000
#         ship       0.74      0.88      0.80      1000
#        truck       0.97      0.46      0.62      1000
#
#     accuracy                           0.63     10000
#    macro avg       0.69      0.63      0.62     10000
# weighted avg       0.69      0.63      0.62     10000
#
# Epoch 2 Step 59 ave_loss 0.7728
# Epoch 2 Step 119 ave_loss 0.7448
# Epoch 2 Step 179 ave_loss 0.7812
# Epoch 2 Step 239 ave_loss 0.7434
# Epoch 2 Step 299 ave_loss 0.7063
# Epoch 2 Step 359 ave_loss 0.7004
#               precision    recall  f1-score   support
#
#        plane       0.84      0.73      0.78      1000
#          car       0.90      0.88      0.89      1000
#         bird       0.80      0.47      0.59      1000
#          cat       0.66      0.42      0.52      1000
#         deer       0.69      0.73      0.71      1000
#          dog       0.69      0.60      0.64      1000
#         frog       0.77      0.81      0.79      1000
#        horse       0.51      0.94      0.67      1000
#         ship       0.88      0.86      0.87      1000
#        truck       0.78      0.88      0.83      1000
#
#     accuracy                           0.73     10000
#    macro avg       0.75      0.73      0.73     10000
# weighted avg       0.75      0.73      0.73     10000
#
# Epoch 3 Step 59 ave_loss 0.6578
# Epoch 3 Step 119 ave_loss 0.6181
# Epoch 3 Step 179 ave_loss 0.6254
# Epoch 3 Step 239 ave_loss 0.6138
# Epoch 3 Step 299 ave_loss 0.6302
# Epoch 3 Step 359 ave_loss 0.5908
#               precision    recall  f1-score   support
#
#        plane       0.74      0.87      0.80      1000
#          car       0.78      0.97      0.86      1000
#         bird       0.82      0.52      0.64      1000
#          cat       0.57      0.62      0.59      1000
#         deer       0.84      0.53      0.65      1000
#          dog       0.61      0.77      0.68      1000
#         frog       0.59      0.91      0.71      1000
#        horse       0.87      0.76      0.81      1000
#         ship       0.96      0.79      0.86      1000
#        truck       0.95      0.71      0.81      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.77      0.74      0.74     10000
# weighted avg       0.77      0.74      0.74     10000
#
# Epoch 4 Step 59 ave_loss 0.5577
# Epoch 4 Step 119 ave_loss 0.5513
# Epoch 4 Step 179 ave_loss 0.5526
# Epoch 4 Step 239 ave_loss 0.5423
# Epoch 4 Step 299 ave_loss 0.5441
# Epoch 4 Step 359 ave_loss 0.5166
#               precision    recall  f1-score   support
#
#        plane       0.83      0.84      0.83      1000
#          car       0.97      0.81      0.88      1000
#         bird       0.79      0.69      0.74      1000
#          cat       0.77      0.55      0.64      1000
#         deer       0.74      0.86      0.80      1000
#          dog       0.66      0.82      0.74      1000
#         frog       0.86      0.84      0.85      1000
#        horse       0.83      0.86      0.85      1000
#         ship       0.88      0.90      0.89      1000
#        truck       0.81      0.92      0.86      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
#
# Epoch 5 Step 59 ave_loss 0.4947
# Epoch 5 Step 119 ave_loss 0.4897
# Epoch 5 Step 179 ave_loss 0.4799
# Epoch 5 Step 239 ave_loss 0.4998
# Epoch 5 Step 299 ave_loss 0.4899
# Epoch 5 Step 359 ave_loss 0.5018
#               precision    recall  f1-score   support
#
#        plane       0.91      0.67      0.77      1000
#          car       0.98      0.77      0.86      1000
#         bird       0.92      0.52      0.67      1000
#          cat       0.66      0.69      0.67      1000
#         deer       0.82      0.77      0.80      1000
#          dog       0.63      0.81      0.71      1000
#         frog       0.76      0.92      0.83      1000
#        horse       0.87      0.81      0.84      1000
#         ship       0.73      0.96      0.83      1000
#        truck       0.80      0.93      0.86      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.81      0.79      0.78     10000
# weighted avg       0.81      0.79      0.78     10000
#
# Epoch 6 Step 59 ave_loss 0.4482
# Epoch 6 Step 119 ave_loss 0.4431
# Epoch 6 Step 179 ave_loss 0.4518
# Epoch 6 Step 239 ave_loss 0.4783
# Epoch 6 Step 299 ave_loss 0.4477
# Epoch 6 Step 359 ave_loss 0.4378
#               precision    recall  f1-score   support
#
#        plane       0.68      0.93      0.79      1000
#          car       0.95      0.91      0.93      1000
#         bird       0.83      0.66      0.74      1000
#          cat       0.78      0.56      0.65      1000
#         deer       0.85      0.74      0.79      1000
#          dog       0.80      0.71      0.75      1000
#         frog       0.79      0.91      0.85      1000
#        horse       0.76      0.90      0.82      1000
#         ship       0.86      0.93      0.89      1000
#        truck       0.92      0.89      0.90      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.82      0.81      0.81     10000
# weighted avg       0.82      0.81      0.81     10000
#
# Epoch 7 Step 59 ave_loss 0.4122
# Epoch 7 Step 119 ave_loss 0.4147
# Epoch 7 Step 179 ave_loss 0.3871
# Epoch 7 Step 239 ave_loss 0.4163
# Epoch 7 Step 299 ave_loss 0.4102
# Epoch 7 Step 359 ave_loss 0.4277
#               precision    recall  f1-score   support
#
#        plane       0.80      0.89      0.84      1000
#          car       0.93      0.92      0.92      1000
#         bird       0.83      0.73      0.78      1000
#          cat       0.64      0.75      0.69      1000
#         deer       0.87      0.76      0.81      1000
#          dog       0.83      0.69      0.76      1000
#         frog       0.82      0.89      0.85      1000
#        horse       0.86      0.88      0.87      1000
#         ship       0.91      0.90      0.90      1000
#        truck       0.87      0.91      0.89      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.84      0.83      0.83     10000
# weighted avg       0.84      0.83      0.83     10000
#
# Epoch 8 Step 59 ave_loss 0.3784
# Epoch 8 Step 119 ave_loss 0.3737
# Epoch 8 Step 179 ave_loss 0.3988
# Epoch 8 Step 239 ave_loss 0.3751
# Epoch 8 Step 299 ave_loss 0.3965
# Epoch 8 Step 359 ave_loss 0.3762
#               precision    recall  f1-score   support
#
#        plane       0.77      0.93      0.84      1000
#          car       0.91      0.95      0.93      1000
#         bird       0.80      0.76      0.78      1000
#          cat       0.69      0.76      0.72      1000
#         deer       0.85      0.82      0.84      1000
#          dog       0.81      0.73      0.77      1000
#         frog       0.83      0.92      0.87      1000
#        horse       0.92      0.86      0.89      1000
#         ship       0.93      0.87      0.90      1000
#        truck       0.95      0.83      0.89      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.85      0.84      0.84     10000
# weighted avg       0.85      0.84      0.84     10000
#
# Epoch 9 Step 59 ave_loss 0.3422
# Epoch 9 Step 119 ave_loss 0.3529
# Epoch 9 Step 179 ave_loss 0.3566
# Epoch 9 Step 239 ave_loss 0.3533
# Epoch 9 Step 299 ave_loss 0.3691
# Epoch 9 Step 359 ave_loss 0.3620
#               precision    recall  f1-score   support
#
#        plane       0.80      0.88      0.84      1000
#          car       0.91      0.96      0.93      1000
#         bird       0.74      0.81      0.77      1000
#          cat       0.83      0.57      0.67      1000
#         deer       0.71      0.89      0.79      1000
#          dog       0.85      0.72      0.78      1000
#         frog       0.80      0.94      0.87      1000
#        horse       0.90      0.86      0.88      1000
#         ship       0.94      0.86      0.90      1000
#        truck       0.94      0.87      0.90      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.83     10000
# weighted avg       0.84      0.84      0.83     10000
